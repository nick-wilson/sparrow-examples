# %%
# !sjef -s molpro erase he

# %%
# !sjef -s molpro new he

# %%
# !sjef -s molpro import he he.inp

# %%
# !sjef -s molpro -b hawk run he
# Out:
# scratch/sjef-project/14935944916599216951
# Job number: 46472458

# %%
# !sjef -s molpro status he
# Out:
# scratch/sjef-project/14935944916599216951
# Running, job number 46472458 on backend hawk

# %%
# !sjef -s molpro browse he
# Out:
# scratch/sjef-project/14935944916599216951
#
#  Primary working directories    : /scratch/c.sacnw3/SLURM.46472458/molpro.RXXruQnPrP
#  Secondary working directories  : /scratch/c.sacnw3/SLURM.46472458/molpro.RXXruQnPrP
#  Wavefunction directory         : /home/c.sacnw3/wfu/
#  Main file repository           : /scratch/c.sacnw3/SLURM.46472458/molpro.RXXruQnPrP/
#
#  id        : cardiff
#
#  Nodes     nprocs
#  ccs2009      1
#
#  Using DEFAULT tuning parameter for ncache   :   16384
#  Using DEFAULT tuning parameter for mflopdgm :   10000
#  Using DEFAULT tuning parameter for mflopdgv :    4000
#  Using DEFAULT tuning parameter for mflopmxm :    5000
#  Using DEFAULT tuning parameter for mflopmxv :    4000
#  Using DEFAULT tuning parameter for mindgm   :       1
#  Using DEFAULT tuning parameter for mindgc   :       4
#  Using DEFAULT tuning parameter for mindgf   :    5000
#  Using DEFAULT tuning parameter for mindgl   :       4
# ...
